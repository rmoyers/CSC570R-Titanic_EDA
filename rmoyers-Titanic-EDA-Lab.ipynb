# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### EDA
# For each variable (other than name)
# <li> Is the variable categorical or continuous
# <li> Are there missing values
# <li> Min, Max, Mean, and Standard Deviation
# <li> Histograms describing the distribution of the variable
# <li> EDA should be completed for these fields:  'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', and 'Embarked'

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Above are values for Min, Max, Mean, and Standard Deviation

# %% [markdown]
# ### EDA for PassengerId

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %% [markdown]
# ### Passenger ID is continuous

# %%
df.PassengerId.hist(bins=20)

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### PassengerId has no missing values

# %% [markdown]
# ### EDA for Survived

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Survived.value_counts().plot(kind="Bar")

# %% [markdown]
# ### Survived is Categorical

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Survived has no missing values

# %% [markdown]
# ### EDA for Pclass

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Pclass is Categorical

# %%
df.Pclass.value_counts().plot(kind="Bar")

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Pclass has no missing values

# %% [markdown]
# ### EDA for Sex

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# ### Sex is Categorical

# %%
df.Sex.value_counts().plot(kind="Bar")

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Sex has no missing values

# %% [markdown]
# ### EDA for Age

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, dtype: int64

# %% [markdown]
# ### Age is Continuous

# %%
df.Age.hist()

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# ### Age has missing values

# %% [markdown]
# ### EDA for SibSp

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# ### SibSp is Categorical. I think this is one of those cases where it is a judgement call. Since there are very few values and most of the data is included in 2 values, I am going to say SibSp is Categorical.

# %%
df.SibSp.hist()

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### SibSp has no missing values

# %% [markdown]
# ### EDA for Parch

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# ### Parch is Categorical. I think this is one of those cases where it is a judgement call. Since there are very few values and most of the data is included in 2 values, I am going to say Parch is Categorical.

# %%
df.Parch.hist()

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Parch has no missing values

# %% [markdown]
# ### EDA for Ticket

# %%
df.Ticket.value_counts()
# Out:
# 1601                  7
# 347082                7
# CA. 2343              7
# 3101295               6
# CA 2144               6
# 347088                6
# 382652                5
# S.O.C. 14879          5
# 113760                4
# W./C. 6608            4
# 113781                4
# PC 17757              4
# 19950                 4
# 4133                  4
# LINE                  4
# 17421                 4
# 349909                4
# 347077                4
# 2666                  4
# C.A. 31921            3
# PC 17760              3
# F.C.C. 13529          3
# 363291                3
# 239853                3
# 29106                 3
# 345773                3
# PC 17755              3
# PC 17582              3
# 24160                 3
# 248727                3
#                      ..
# PC 17483              1
# 13213                 1
# 2674                  1
# 347743                1
# SOTON/OQ 392082       1
# 244278                1
# SOTON/O.Q. 3101305    1
# ...

# %% [markdown]
# ### Ticket is Continuous

# %%
df.Ticket.value_counts().plot(kind="Bar")

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Ticket has no missing values

# %% [markdown]
# ### EDA for Fare

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %% [markdown]
# ### Fare is Continuous

# %%
df.Fare.hist(bins=50)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Fare has no missing values

# %% [markdown]
# ### EDA for Cabin

# %%
df.Cabin.value_counts()
# Out:
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# C22 C26        3
# D              3
# F33            3
# E101           3
# C52            2
# B58 B60        2
# E121           2
# C125           2
# B22            2
# E24            2
# E8             2
# B28            2
# B49            2
# D26            2
# D36            2
# C126           2
# B20            2
# B18            2
# C2             2
# B35            2
# E44            2
# B77            2
# E33            2
# F4             2
# C123           2
# E25            2
#               ..
# B38            1
# E49            1
# E40            1
# A5             1
# A6             1
# E50            1
# D47            1
# D37            1
# E58            1
# E31            1
# C85            1
# E10            1
# B73            1
# B30            1
# C50            1
# A7             1
# E68            1
# A31            1
# B71            1
# E38            1
# E36            1
# ...

# %% [markdown]
# ### Cabin is Continuous

# %%
df.Cabin.value_counts().plot(kind="bar")

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# ### Cabin has missing values

# %% [markdown]
# ### EDA for Embarked

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### Embarked is Categorical

# %%
df.Embarked.value_counts().plot(kind="bar")

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ### Embarked has missing values
